# %% [markdown]
# # Project 2: Features, Galore: A Linear Regression Analysis on Home Features Predicting Sale Price
# ---
#
# ## Test Model and Kaggle Submission
#
# This section includes running the test data through the optimal Linear Regression model. The model used is the regular Linear Regression with all non multi-collinear features. Predicted home sale price values are determined for submission in the Ames Housing Kaggle Competition.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
#Read in files 
Z_train=pd.read_csv('../datasets/z_train_final.csv')
Z_test_data=pd.read_csv('../datasets/clean_test.csv')
y_train=pd.read_csv('../datasets/y_train_cleaned.csv')

# %%
#Debugging code 
Z_test_data = Z_test_data.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
Z_train.head()
# Out:
#    index    id        pid  lot_frontage  lot_area  lot_shape  utilities  \
# 0   1957   239  905452110     -0.921358 -0.106446   0.718504        0.0
# 1   1966  2443  528315030      0.643738 -0.089214   0.718504        0.0
# 2    838   441  528120170      0.399191  0.150689  -1.039629        0.0
# 3    427  1379  905103030      0.545919  0.512571   0.718504        0.0
# 4   1489  1218  534428020     -0.040992  0.424550  -1.039629        0.0
#
#    land_slope  overall_qual  overall_cond  ...  misc_feature_Othr  \
# 0    0.218298     -1.478840      0.389398  ...          -0.042848
# 1    0.218298      1.337753     -0.505889  ...          -0.042848
# 2    0.218298      2.041901     -0.505889  ...          -0.042848
# 3    0.218298     -0.070544     -0.505889  ...          -0.042848
# 4    0.218298     -1.478840     -0.505889  ...          -0.042848
#
#    misc_feature_Shed  sale_type_CWD  sale_type_Con  sale_type_ConLD  \
# 0           -0.14781      -0.065532      -0.034975         -0.08947
# 1           -0.14781      -0.065532      -0.034975         -0.08947
# 2           -0.14781      -0.065532      -0.034975         -0.08947
# 3           -0.14781      -0.065532      -0.034975         -0.08947
# 4           -0.14781      -0.065532      -0.034975         -0.08947
#
#    sale_type_ConLI  sale_type_ConLw  sale_type_New  sale_type_Oth  \
# 0        -0.055351        -0.049492      -0.298588      -0.049492
# 1        -0.055351        -0.049492      -0.298588      -0.049492
# 2        -0.055351        -0.049492      -0.298588      -0.049492
# 3        -0.055351        -0.049492      -0.298588      -0.049492
# 4        -0.055351        -0.049492      -0.298588      -0.049492
#
#    sale_type_WD
# 0       0.395061
# 1       0.395061
# 2       0.395061
# 3       0.395061
# 4       0.395061
#
# [5 rows x 165 columns]

# %%
Z_train=Z_train.set_index('index')

# %%
Z_train.head()
# Out:
#          id        pid  lot_frontage  lot_area  lot_shape  utilities  \
# index
# 1957    239  905452110     -0.921358 -0.106446   0.718504        0.0
# 1966   2443  528315030      0.643738 -0.089214   0.718504        0.0
# 838     441  528120170      0.399191  0.150689  -1.039629        0.0
# 427    1379  905103030      0.545919  0.512571   0.718504        0.0
# 1489   1218  534428020     -0.040992  0.424550  -1.039629        0.0
#
#        land_slope  overall_qual  overall_cond  year_remod/add  ...  \
# index                                                          ...
# 1957     0.218298     -1.478840      0.389398       -0.268166  ...
# 1966     0.218298      1.337753     -0.505889        0.644691  ...
# 838      0.218298      2.041901     -0.505889        1.029051  ...
# 427      0.218298     -0.070544     -0.505889       -0.316211  ...
# 1489     0.218298     -1.478840     -0.505889       -1.181023  ...
#
#        misc_feature_Othr  misc_feature_Shed  sale_type_CWD  sale_type_Con  \
# index
# 1957           -0.042848           -0.14781      -0.065532      -0.034975
# 1966           -0.042848           -0.14781      -0.065532      -0.034975
# 838            -0.042848           -0.14781      -0.065532      -0.034975
# 427            -0.042848           -0.14781      -0.065532      -0.034975
# 1489           -0.042848           -0.14781      -0.065532      -0.034975
#
#        sale_type_ConLD  sale_type_ConLI  sale_type_ConLw  sale_type_New  \
# index
# 1957          -0.08947        -0.055351        -0.049492      -0.298588
# 1966          -0.08947        -0.055351        -0.049492      -0.298588
# 838           -0.08947        -0.055351        -0.049492      -0.298588
# 427           -0.08947        -0.055351        -0.049492      -0.298588
# 1489          -0.08947        -0.055351        -0.049492      -0.298588
#
#        sale_type_Oth  sale_type_WD
# index
# 1957       -0.049492       0.395061
# 1966       -0.049492       0.395061
# 838        -0.049492       0.395061
# 427        -0.049492       0.395061
# 1489       -0.049492       0.395061
#
# [5 rows x 164 columns]

# %%
Z_train.shape
# Out:
# (1637, 164)

# %%
y_train.shape
# Out:
# (1637, 2)

# %%
y_train.head()
# Out:
#    Unnamed: 0  sale_price
# 0        1957      127000
# 1        1966      348000
# 2         838      300000
# 3         427      157500
# 4        1489      141000

# %%
y_train.rename(columns={"Unnamed: 0": "index"}, inplace=True)
y_train=y_train.set_index('index')

# %%
y_train.head(2)
# Out:
#        sale_price
# index
# 1957       127000
# 1966       348000

# %%
Z_test_data.head()
# Out:
#    Unnamed: 0    id        pid  lot_frontage  lot_area  lot_shape  utilities  \
# 0           0  2658  902301120      0.007918 -0.141587   0.718504        0.0
# 1           1  2718  905108090     -0.040992 -0.053735  -1.039629        0.0
# 2           2  2414  528218130     -0.530084  1.203559  -1.039629        0.0
# 3           3  1989  902207150     -0.432266 -0.246671   0.718504        0.0
# 4           4   625  535105100     -0.040992 -0.081105  -1.039629        0.0
#
#    land_slope  overall_qual  overall_cond  ...  misc_feature_Othr  \
# 0    0.218298     -0.070544      2.179972  ...          -0.042848
# 1    0.218298     -0.774692     -1.401176  ...          -0.042848
# 2    0.218298      0.633604     -0.505889  ...          -0.042848
# 3    0.218298     -0.774692      0.389398  ...          -0.042848
# 4    0.218298     -0.070544     -0.505889  ...          -0.042848
#
#    misc_feature_Shed  sale_type_CWD  sale_type_Con  sale_type_ConLD  \
# 0           -0.14781      -0.065532      -0.034975         -0.08947
# 1           -0.14781      -0.065532      -0.034975         -0.08947
# 2           -0.14781      -0.065532      -0.034975         -0.08947
# 3           -0.14781      -0.065532      -0.034975         -0.08947
# 4           -0.14781      -0.065532      -0.034975         -0.08947
#
#    sale_type_ConLI  sale_type_ConLw  sale_type_New  sale_type_Oth  \
# 0        -0.055351        -0.049492      -0.298588      -0.049492
# 1        -0.055351        -0.049492      -0.298588      -0.049492
# 2        -0.055351        -0.049492       3.349092      -0.049492
# 3        -0.055351        -0.049492      -0.298588      -0.049492
# 4        -0.055351        -0.049492      -0.298588      -0.049492
#
#    sale_type_WD
# 0       0.395061
# 1       0.395061
# 2      -2.531253
# 3       0.395061
# 4       0.395061
#
# [5 rows x 165 columns]

# %%
Z_test_data.rename(columns={"Unnamed: 0": "index"}, inplace=True)
Z_test_data=Z_test_data.set_index('index')

# %%
Z_test_data.head()
# Out:
#          id        pid  lot_frontage  lot_area  lot_shape  utilities  \
# index
# 0      2658  902301120      0.007918 -0.141587   0.718504        0.0
# 1      2718  905108090     -0.040992 -0.053735  -1.039629        0.0
# 2      2414  528218130     -0.530084  1.203559  -1.039629        0.0
# 3      1989  902207150     -0.432266 -0.246671   0.718504        0.0
# 4       625  535105100     -0.040992 -0.081105  -1.039629        0.0
#
#        land_slope  overall_qual  overall_cond  year_remod/add  ...  \
# index                                                          ...
# 0        0.218298     -0.070544      2.179972       -1.661474  ...
# 1        0.218298     -0.774692     -1.401176       -0.364256  ...
# 2        0.218298      0.633604     -0.505889        1.029051  ...
# 3        0.218298     -0.774692      0.389398        1.029051  ...
# 4        0.218298     -0.070544     -0.505889       -1.036888  ...
#
#        misc_feature_Othr  misc_feature_Shed  sale_type_CWD  sale_type_Con  \
# index
# 0              -0.042848           -0.14781      -0.065532      -0.034975
# 1              -0.042848           -0.14781      -0.065532      -0.034975
# 2              -0.042848           -0.14781      -0.065532      -0.034975
# 3              -0.042848           -0.14781      -0.065532      -0.034975
# 4              -0.042848           -0.14781      -0.065532      -0.034975
#
#        sale_type_ConLD  sale_type_ConLI  sale_type_ConLw  sale_type_New  \
# index
# 0             -0.08947        -0.055351        -0.049492      -0.298588
# 1             -0.08947        -0.055351        -0.049492      -0.298588
# 2             -0.08947        -0.055351        -0.049492       3.349092
# 3             -0.08947        -0.055351        -0.049492      -0.298588
# 4             -0.08947        -0.055351        -0.049492      -0.298588
#
#        sale_type_Oth  sale_type_WD
# index
# 0          -0.049492       0.395061
# 1          -0.049492       0.395061
# 2          -0.049492      -2.531253
# 3          -0.049492       0.395061
# 4          -0.049492       0.395061
#
# [5 rows x 164 columns]

# %%
#Renaming unnamed 0 and setting it to the index
Z_test_data.rename(columns={"Unnamed: 0": "index"}, inplace=True)

# %%
Z_test_data.head(2)
# Out:
#          id        pid  lot_frontage  lot_area  lot_shape  utilities  \
# index
# 0      2658  902301120      0.007918 -0.141587   0.718504        0.0
# 1      2718  905108090     -0.040992 -0.053735  -1.039629        0.0
#
#        land_slope  overall_qual  overall_cond  year_remod/add  ...  \
# index                                                          ...
# 0        0.218298     -0.070544      2.179972       -1.661474  ...
# 1        0.218298     -0.774692     -1.401176       -0.364256  ...
#
#        misc_feature_Othr  misc_feature_Shed  sale_type_CWD  sale_type_Con  \
# index
# 0              -0.042848           -0.14781      -0.065532      -0.034975
# 1              -0.042848           -0.14781      -0.065532      -0.034975
#
#        sale_type_ConLD  sale_type_ConLI  sale_type_ConLw  sale_type_New  \
# index
# 0             -0.08947        -0.055351        -0.049492      -0.298588
# 1             -0.08947        -0.055351        -0.049492      -0.298588
#
#        sale_type_Oth  sale_type_WD
# index
# 0          -0.049492       0.395061
# 1          -0.049492       0.395061
#
# [2 rows x 164 columns]

# %%
Z_test_data.head()
# Out:
#          id        pid  lot_frontage  lot_area  lot_shape  utilities  \
# index
# 0      2658  902301120      0.007918 -0.141587   0.718504        0.0
# 1      2718  905108090     -0.040992 -0.053735  -1.039629        0.0
# 2      2414  528218130     -0.530084  1.203559  -1.039629        0.0
# 3      1989  902207150     -0.432266 -0.246671   0.718504        0.0
# 4       625  535105100     -0.040992 -0.081105  -1.039629        0.0
#
#        land_slope  overall_qual  overall_cond  year_remod/add  ...  \
# index                                                          ...
# 0        0.218298     -0.070544      2.179972       -1.661474  ...
# 1        0.218298     -0.774692     -1.401176       -0.364256  ...
# 2        0.218298      0.633604     -0.505889        1.029051  ...
# 3        0.218298     -0.774692      0.389398        1.029051  ...
# 4        0.218298     -0.070544     -0.505889       -1.036888  ...
#
#        misc_feature_Othr  misc_feature_Shed  sale_type_CWD  sale_type_Con  \
# index
# 0              -0.042848           -0.14781      -0.065532      -0.034975
# 1              -0.042848           -0.14781      -0.065532      -0.034975
# 2              -0.042848           -0.14781      -0.065532      -0.034975
# 3              -0.042848           -0.14781      -0.065532      -0.034975
# 4              -0.042848           -0.14781      -0.065532      -0.034975
#
#        sale_type_ConLD  sale_type_ConLI  sale_type_ConLw  sale_type_New  \
# index
# 0             -0.08947        -0.055351        -0.049492      -0.298588
# 1             -0.08947        -0.055351        -0.049492      -0.298588
# 2             -0.08947        -0.055351        -0.049492       3.349092
# 3             -0.08947        -0.055351        -0.049492      -0.298588
# 4             -0.08947        -0.055351        -0.049492      -0.298588
#
#        sale_type_Oth  sale_type_WD
# index
# 0          -0.049492       0.395061
# 1          -0.049492       0.395061
# 2          -0.049492      -2.531253
# 3          -0.049492       0.395061
# 4          -0.049492       0.395061
#
# [5 rows x 164 columns]

# %%
#Dropping Utilities because scaled stange 
Z_train.drop(columns='utilities', inplace=True)
Z_test_data.drop(columns='utilities', inplace=True)

# %%
Z_test_data_id=Z_test_data['id']

# %%
Z_test_data_id.head(2)
# Out:
# index
# 0    2658
# 1    2718
# Name: id, dtype: int64

# %%
#Dropping id and PID for the model 
Z_train=Z_train.drop(columns=['id', 'pid'])
Z_test_data=Z_test_data.drop(columns=['id', 'pid'])

# %%
#Instantiate Best Model 
lr=LinearRegression()

# %%
y_train.mean()
# Out:
# sale_price    181428.810629
# dtype: float64

# %%
#fit best model 
lr.fit(Z_train, y_train)
# Out:
# LinearRegression()

# %%
#Train score
lr.score(Z_train, y_train)
# Out:
# 0.9260161478331302

# %%
#Test data predictions 
lr.predict(Z_test_data)[:10]
# Out:
# array([[136442.89700431],
#        [149311.39700431],
#        [219489.14700431],
#        [109502.64700431],
#        [176698.64700431],
#        [ 81676.14700431],
#        [103176.14700431],
#        [153353.14700431],
#        [174791.39700431],
#        [171163.89700431]])

# %%
#Creating an empty dataframe 
kaggle=pd.DataFrame()

# %%
#Making preds into a Dataframe 
kaggle['Id']=Z_test_data_id

# %%
#Creating a Sale Price column 
kaggle['SalePrice']=lr.predict(Z_test_data)

# %%
#Check 
kaggle.head()
# Out:
#          Id      SalePrice
# index
# 0      2658  136442.897004
# 1      2718  149311.397004
# 2      2414  219489.147004
# 3      1989  109502.647004
# 4       625  176698.647004

# %%
#Check 
kaggle.tail()
# Out:
#          Id      SalePrice
# index
# 873    1662  202681.397004
# 874    1234  223856.647004
# 875    1373  118805.397004
# 876    1672  104844.397004
# 877    1939  113981.147004

# %% [markdown]
# #### The below code is not best practice for this assignment but necessary due to issues with kaggle submission

# %%
sorted_df = kaggle.sort_values(by=['Id'], ascending=True)

# %%
sorted_df = sorted_df.sort_index(ascending=True)

# %%
sorted_df=sorted_df.reset_index().drop(columns='Id')
sorted_df
# Out:
#      index      SalePrice
# 0        0  136442.897004
# 1        1  149311.397004
# 2        2  219489.147004
# 3        3  109502.647004
# 4        4  176698.647004
# ..     ...            ...
# 873    873  202681.397004
# 874    874  223856.647004
# 875    875  118805.397004
# 876    876  104844.397004
# 877    877  113981.147004
#
# [878 rows x 2 columns]

# %%
kaggle=sorted_df.rename(columns={'index':'Id', 'SalePrice':'sample_soln'})

# %%
kaggle=kaggle[:260]

# %%
kaggle
# Out:
#       Id    sample_soln
# 0      0  136442.897004
# 1      1  149311.397004
# 2      2  219489.147004
# 3      3  109502.647004
# 4      4  176698.647004
# ..   ...            ...
# 255  255  110258.397004
# 256  256   76778.147004
# 257  257  418435.397004
# 258  258  209466.147004
# 259  259  233944.397004
#
# [260 rows x 2 columns]

# %%
#Saving kaggle as a csv
kaggle.to_csv('submission_lr.csv', index=False)
